# %% [markdown]
# **Copied code from the data_loading file to display the projection on the map and the data points for the stations.**

# %%
from pathlib import Path
import zipfile
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx
import random
from shapely.geometry import LineString
import numpy as np
import networkx as nx

# %%
GTFS_PATH = Path("../data/raw/GTFS_Copenhagen.zip")

if not GTFS_PATH.exists():
    raise FileNotFoundError(
        "GTFS ZIP not found. Download it as described in README.md"
    )
    
with zipfile.ZipFile(GTFS_PATH, "r") as z:
    stops = pd.read_csv(z.open("GTFS_Copenhagen/stops.txt"))
    routes = pd.read_csv(z.open("GTFS_Copenhagen/routes.txt"))
    shapes = pd.read_csv(z.open("GTFS_Copenhagen/shapes.txt"))
    stop_times = pd.read_csv(z.open("GTFS_Copenhagen/stop_times.txt"))
    trips = pd.read_csv(z.open("GTFS_Copenhagen/trips.txt"))
# Out:
# /tmp/ipykernel_282180/146572828.py:12: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   stop_times = pd.read_csv(z.open("GTFS_Copenhagen/stop_times.txt"))

# %%
# stops filtering for metro only
metro_stops = stops[stops['stop_name'].str.contains('(Metro)')]

# remove the line based on stop_id
metro_stops = metro_stops[metro_stops["stop_id"] != 821004401]

print(len(metro_stops))
# Out:
# 44
# /tmp/ipykernel_282180/2102663247.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   metro_stops = stops[stops['stop_name'].str.contains('(Metro)')]

# %%
# Stops GeoDataFrame (WGS84)
gdf_stops = gpd.GeoDataFrame(
    metro_stops,
    geometry=gpd.points_from_xy(metro_stops.stop_lon, metro_stops.stop_lat),
    crs="EPSG:4326"
)

# %% [markdown]
# **Making graph in networkX**

# %%
## Make a empty graph and import nodes based on lat and lon
G = nx.Graph()

gdf_stops_3857 = gdf_stops.to_crs(epsg=3857)

for name, row in gdf_stops_3857.iterrows():
    G.add_node(row["stop_name"], lat=row["stop_lat"], lon=row["stop_lon"])

      
gdf_stops_3857.head()
# Out:
#     stop_id stop_code                   stop_name  stop_desc   stop_lat  \
# 51  8603317       NaN      Vestamager St. (Metro)        NaN  55.619391
# 52  8603315       NaN         Ørestad St. (Metro)        NaN  55.629055
# 53  8603312       NaN          Sundby St. (Metro)        NaN  55.645199
# 54  8603313       NaN    Bella Center St. (Metro)        NaN  55.638051
# 55  8603310       NaN  Islands Brygge St. (Metro)        NaN  55.663422
#
#      stop_lon  location_type  parent_station  wheelchair_boarding  \
# 51  12.575297              0             NaN                    0
# 52  12.579389              0             NaN                    0
# 53  12.585728              0             NaN                    0
# 54  12.582928              0             NaN                    0
# 55  12.585217              0             NaN                    0
#
#     platform_code                         geometry
# 51            NaN  POINT (1399875.659 7483017.289)
# 52            NaN  POINT (1400331.178 7484922.633)
# 53            NaN  POINT (1401036.832 7488106.615)
# 54            NaN  POINT (1400725.138 7486696.697)
# 55            NaN  POINT (1400979.948 7491702.202)

# %%
pos = {name: (geom.x, geom.y) for name, geom in zip(gdf_stops_3857["stop_name"], gdf_stops_3857.geometry)}

fig, ax = plt.subplots(figsize=(8,8))

nx.draw(G, pos,
        node_size=8,
        edge_color="gray",
        node_color="blue",
        ax=ax,
        with_labels=False)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron)

ax.set_axis_off()
plt.show()

# %%
# EDA of G graph
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
print("Nodes:", G.nodes(data=True))
# Out:
# Number of nodes: 44
# Number of edges: 0
# Nodes: [('Vestamager St. (Metro)', {'lat': 55.619391, 'lon': 12.575297}), ('Ørestad St. (Metro)', {'lat': 55.629055, 'lon': 12.579389}), ('Sundby St. (Metro)', {'lat': 55.645199, 'lon': 12.585728}), ('Bella Center St. (Metro)', {'lat': 55.638051, 'lon': 12.582928}), ('Islands Brygge St. (Metro)', {'lat': 55.663422, 'lon': 12.585217}), ('DR Byen St. (Metro)', {'lat': 55.655813, 'lon': 12.58899}), ('Kongens Nytorv St. (Metro)', {'lat': 55.679185, 'lon': 12.585228}), ('Christianshavn St. (Metro)', {'lat': 55.672054, 'lon': 12.591385}), ('Forum St. (Metro)', {'lat': 55.681821, 'lon': 12.552431}), ('Nørreport St. (Metro)', {'lat': 55.683843, 'lon': 12.571044}), ('Fasanvej St. (Metro)', {'lat': 55.681669, 'lon': 12.523102}), ('Frederiksberg St. (Metro)', {'lat': 55.681223, 'lon': 12.531719}), ('Flintholm St. (Metro)', {'lat': 55.685868, 'lon': 12.499527}), ('Lindevang St. (Metro)', {'lat': 55.683482, 'lon': 12.512873}), ('Vanløse St. (Metro)', {'lat': 55.687297, 'lon': 12.491664}), ('Lergravsparken St. (Metro)', {'lat': 55.662101, 'lon': 12.616417}), ('Amagerbro St. (Metro)', {'lat': 55.663326, 'lon': 12.602929}), ('Øresund St. (Metro)', {'lat': 55.661701, 'lon': 12.628453}), ('Amager Strand St. (Metro)', {'lat': 55.656519, 'lon': 12.631584}), ('Femøren St. (Metro)', {'lat': 55.645348, 'lon': 12.638324}), ('Kastrup St. (Metro)', {'lat': 55.635747, 'lon': 12.646732}), ('Københavns Lufthavn St. (Metro)', {'lat': 55.630137, 'lon': 12.64939}), ('København H (Metro)', {'lat': 55.671941, 'lon': 12.56412}), ('Enghave Plads St. (Metro)', {'lat': 55.667284, 'lon': 12.545814}), ('Frederiksberg Allé St. (Metro)', {'lat': 55.673727, 'lon': 12.540351}), ('Aksel Møllers Have St. (Metro)', {'lat': 55.686378, 'lon': 12.533187}), ('Nuuks Plads St. (Metro)', {'lat': 55.688796, 'lon': 12.542892}), ('Nørrebros Runddel St. (Metro)', {'lat': 55.693945, 'lon': 12.548899}), ('Nørrebro St. (Metro)', {'lat': 55.700552, 'lon': 12.538082}), ('Skjolds Plads St. (Metro)', {'lat': 55.70328, 'lon': 12.548233}), ('Vibenshus Runddel St. (Metro)', {'lat': 55.706284, 'lon': 12.564}), ('Poul Henningsens Plads St. (Metro)', {'lat': 55.70925, 'lon': 12.576709}), ('Trianglen St. (Metro)', {'lat': 55.699135, 'lon': 12.57607}), ('Østerport St. (Metro)', {'lat': 55.693217, 'lon': 12.585352}), ('Marmorkirken St. (Metro)', {'lat': 55.685245, 'lon': 12.588632}), ('Gammel Strand St. (Metro)', {'lat': 55.677749, 'lon': 12.579575}), ('Rådhuspladsen St. (Metro)', {'lat': 55.676373, 'lon': 12.568803}), ('Nordhavn St. (Metro)', {'lat': 55.707298, 'lon': 12.591834}), ('Orientkaj St. (Metro)', {'lat': 55.711612, 'lon': 12.595272}), ('København Syd St. (Metro)', {'lat': 55.65253, 'lon': 12.516427}), ('Havneholmen St. (Metro)', {'lat': 55.66091, 'lon': 12.559426}), ('Enghave Brygge St. (Metro)', {'lat': 55.653766, 'lon': 12.556169}), ('Sluseholmen St. (Metro)', {'lat': 55.645836, 'lon': 12.543747}), ('Mozarts Plads St. (Metro)', {'lat': 55.649049, 'lon': 12.533956})]

# %% [markdown]
# **Basic Genetic Algorithm, or connections of points by algorithm**

# %%
# set parameters for algorithm
n_startnodes = 4
n_maxnodes = 12

n_maxroutes = 4
# prob_mutation = .05 # mutation probability
# n_parents = 20 # how many "parents" for "crossovers" to select per generation
# n_kids = 50 # how many kids to generate for each generation
n_iterations = 100 # how many times to iterate

# find total demand for specific OD set
# total_demand = sum(od.trajcount)

# seed
random.seed(161)

# %%
n = 44

origins = gdf_stops_3857.sample(n=n, replace=True).copy().reset_index(drop=True)
destinations = gdf_stops_3857.sample(n=n, replace=True).copy().reset_index(drop=True)

od = origins[["stop_id","stop_name", "geometry"]].copy()
od = od.rename(columns={"stop_id": "origin_id", "stop_name": "origin_name", "geometry": "origin_geom"})

od["destination_id"] = destinations["stop_id"]
od["destination_name"] = destinations["stop_name"]
od["destination_geom"] = destinations["geometry"]

od = od.set_geometry(od.apply(lambda row: LineString([row.origin_geom, row.destination_geom]), axis=1))

od.head()
# Out:
#    origin_id                 origin_name                      origin_geom  \
# 0    8603315         Ørestad St. (Metro)  POINT (1400331.178 7484922.633)
# 1    8603322  Lergravsparken St. (Metro)  POINT (1404453.116 7491441.499)
# 2    8603305   Frederiksberg St. (Metro)  POINT (1395024.578 7495216.141)
# 3    8603323         Øresund St. (Metro)  POINT (1405792.957 7491362.559)
# 4    8603347     Havneholmen St. (Metro)  POINT (1398108.907 7491206.459)
#
#    destination_id            destination_name  \
# 0         8603308  Kongens Nytorv St. (Metro)
# 1         8603307       Nørreport St. (Metro)
# 2         8603322  Lergravsparken St. (Metro)
# 3         8603313    Bella Center St. (Metro)
# 4         8603302       Flintholm St. (Metro)
#
#                   destination_geom  \
# 0  POINT (1400981.172 7494813.756)
# 1  POINT (1399402.217 7495733.467)
# 2  POINT (1404453.116 7491441.499)
# 3  POINT (1400725.138 7486696.697)
# 4  POINT (1391440.981 7496133.333)
#
#                                             geometry
# 0  LINESTRING (1400331.178 7484922.633, 1400981.1...
# 1  LINESTRING (1404453.116 7491441.499, 1399402.2...
# 2  LINESTRING (1395024.578 7495216.141, 1404453.1...
# 3  LINESTRING (1405792.957 7491362.559, 1400725.1...
# 4  LINESTRING (1398108.907 7491206.459, 1391440.9...

# %%
fig, ax = plt.subplots(1,1, figsize = (10,10))
od. plot(ax=ax, color="blue" , alpha=0.5)
gdf_stops_3857.plot(ax=ax, color="red", markersize=10)
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron)

# %% [markdown]
# With this setup, I don't like that some nodes are isolated, and it makes no sense to connect nodes with the greatest distance.
#
# Need to implement max distance of teh edge.
# Check along all nodes in that distance(k-neighbours) and then connected to them.

# %%
# set max distance, meters, eqvialent to the distance betwee København H and Enghave plads
max_distance = 1300
# for 1300m, it is way less stations, seems like it is too small distance for metro 

def knn_edges_projected(gdf, id_col="stop_id", k=3, max_dist=None):
    """
    gdf: GeoDataFrame with Point geometry in a projected CRS (meters).
    max_dist: meters (optional). If set, drop neighbors farther than max_dist.
    Returns: DataFrame of edges (u, v, dist_m)
    """
    if gdf.crs is None:
        raise ValueError("gdf.crs is None. Set CRS before running kNN.")

    # If CRS is geographic (lat/lon), distances won't be meters → reproject
    if gdf.crs.is_geographic:
        # good general fallback for city scale; better: local UTM
        gdf = gdf.to_crs(3857)

    gdf = gdf[[id_col, "geometry"]].dropna().reset_index(drop=True)
    
    print(gdf.head())
    
    # coordinates in meters
    xs = gdf.geometry.x.to_numpy()
    ys = gdf.geometry.y.to_numpy()

    sindex = gdf.sindex
    edges = []

    for i, (u, x, y, geom) in enumerate(zip(gdf[id_col], xs, ys, gdf.geometry)):
        # Expand search window until we have enough candidates
        # (simple heuristic; works well for metro-scale datasets)
        r = 200.0  # start radius (m)
        cand_idx = []
        while len(cand_idx) < (k + 1):  # +1 includes itself
            bbox = (x - r, y - r, x + r, y + r)
            cand_idx = list(sindex.intersection(bbox))
            r *= 2
            if r > 50000:  # safety stop
                break

        # Compute distances to candidates
        dx = xs[cand_idx] - x
        dy = ys[cand_idx] - y
        d = np.hypot(dx, dy)

        # Sort by distance, skip itself
        order = np.argsort(d)
        picked = []
        for idx_in_list in order:
            j = cand_idx[idx_in_list]
            if j == i:
                continue
            dist_m = float(d[idx_in_list])
            if (max_dist is not None) and (dist_m > max_dist):
                continue
            picked.append((i, j, dist_m))
            if len(picked) >= k:
                break

        for _, j, dist_m in picked:
            v = gdf.loc[j, id_col]
            # undirected unique edge
            a, b = sorted((u, v))
            edges.append((a, b, dist_m))

    return pd.DataFrame(edges, columns=["u", "v", "dist_m"]).drop_duplicates()

edges = knn_edges_projected(gdf_stops_3857, id_col="stop_id", k=2, max_dist=2000)
print(edges.head())
# Out:
#    stop_id                         geometry
# 0  8603317  POINT (1399875.659 7483017.289)
# 1  8603315  POINT (1400331.178 7484922.633)
# 2  8603312  POINT (1401036.832 7488106.615)
# 3  8603313  POINT (1400725.138 7486696.697)
# 4  8603310  POINT (1400979.948 7491702.202)
#          u        v       dist_m
# 0  8603315  8603317  1959.038650
# 1  8603313  8603315  1817.280044
# 3  8603312  8603313  1443.960527
# 6  8603310  8603311  1559.174284
# 7  8603309  8603310  1836.918481

# %%
# 2) build LineString geometry for each edge
stops_plot = gdf_stops_3857.set_index("stop_id")

def make_line(row):
    p1 = stops_plot.loc[row["u"], "geometry"]
    p2 = stops_plot.loc[row["v"], "geometry"]
    return LineString([p1, p2])

edges_gdf = gpd.GeoDataFrame(
    edges.copy(),
    geometry=edges.apply(make_line, axis=1),
    crs=gdf_stops_3857.crs
)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))

edges_gdf.plot(ax=ax, color="blue", alpha=0.5, linewidth=1)
gdf_stops_3857.plot(ax=ax, color="red", markersize=10)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron, crs=gdf_stops_3857.crs)

ax.set_axis_off()
ax.set_aspect("equal")
plt.show()

# %%
def knn_edges_projected(gdf, id_col="stop_id", k=3, max_dist=None):
    """
    gdf: GeoDataFrame with Point geometry in a projected CRS (meters).
    max_dist: meters (optional). If set, drop neighbors farther than max_dist.
    Returns: DataFrame of edges (u, v, dist_m)
    """
    if gdf.crs is None:
        raise ValueError("gdf.crs is None. Set CRS before running kNN.")

    # If CRS is geographic (lat/lon), distances won't be meters → reproject
    gdf_utm = gdf.to_crs(gdf.estimate_utm_crs())

    gdf = gdf_utm[[id_col, "geometry"]].dropna().reset_index(drop=True)
    
    print(gdf.head())
    
    # coordinates in meters
    xs = gdf.geometry.x.to_numpy()
    ys = gdf.geometry.y.to_numpy()

    sindex = gdf.sindex
    edges = []

    for i, (u, x, y, geom) in enumerate(zip(gdf[id_col], xs, ys, gdf.geometry)):
        # Expand search window until we have enough candidates
        # (simple heuristic; works well for metro-scale datasets)
        r = 200.0  # start radius (m)
        cand_idx = []
        while len(cand_idx) < (k + 1):  # +1 includes itself
            bbox = (x - r, y - r, x + r, y + r)
            cand_idx = list(sindex.intersection(bbox))
            r *= 2
            if r > 50000:  # safety stop
                break

        # Compute distances to candidates
        dx = xs[cand_idx] - x
        dy = ys[cand_idx] - y
        d = np.hypot(dx, dy)

        # Sort by distance, skip itself
        order = np.argsort(d)
        picked = []
        for idx_in_list in order:
            j = cand_idx[idx_in_list]
            if j == i:
                continue
            dist_m = float(d[idx_in_list])
            if (max_dist is not None) and (dist_m > max_dist):
                continue
            picked.append((i, j, dist_m))
            if len(picked) >= k:
                break

        for _, j, dist_m in picked:
            v = gdf.loc[j, id_col]
            # undirected unique edge
            a, b = sorted((u, v))
            edges.append((a, b, dist_m))

    return pd.DataFrame(edges, columns=["u", "v", "dist_m"]).drop_duplicates()

edges_new = knn_edges_projected(gdf_stops_3857, id_col="stop_id", k=2, max_dist=1500)
print(edges_new.head())
# Out:
#    stop_id                        geometry
# 0  8603317  POINT (347310.264 6166387.238)
# 1  8603315  POINT (347605.405 6167453.405)
# 2  8603312    POINT (348066.915 6169235.6)
# 3  8603313  POINT (347863.034 6168446.486)
# 4  8603310  POINT (348105.355 6171264.121)
#          u        v       dist_m
# 0  8603315  8603317  1106.264502
# 1  8603313  8603315  1025.954324
# 3  8603312  8603313   815.026663
# 4  8603311  8603312  1199.284699
# 7  8603310  8603311   879.704177

# %%
stops_plot = gdf_stops_3857.set_index("stop_id")

def make_line(row):
    p1 = stops_plot.loc[row["u"], "geometry"]
    p2 = stops_plot.loc[row["v"], "geometry"]
    return LineString([p1, p2])

edges_gdf_new = gpd.GeoDataFrame(
    edges_new.copy(),
    geometry=edges_new.apply(make_line, axis=1),
    crs=gdf_stops_3857.crs
)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))

edges_gdf_new.plot(ax=ax, color="blue", alpha=0.5, linewidth=1)
gdf_stops_3857.plot(ax=ax, color="red", markersize=10)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron, crs=gdf_stops_3857.crs)

ax.set_axis_off()
ax.set_aspect("equal")
plt.show()

# %% [markdown]
# Parameters:
#
# - max_routes = 4 , the amount of metro lines
# - max_stops = 17 (red line), so the metro line is not longer than actual one
# - max_distance , distance between stops
# -

# %%
def neighbore_threshold_and_edge_dist(gdf_stops_3857):
    dict_nodes = {}

    gdf_utm = gdf_stops_3857.to_crs(gdf_stops_3857.estimate_utm_crs())
    gdf = gdf_utm[["stop_name", "geometry"]].dropna().reset_index(drop=True)
    # print(gdf)

    # x, y coordinates compatable to meters - two lists of coordinates
    xs = gdf.geometry.x.to_numpy()
    ys = gdf.geometry.y.to_numpy()

    threshold = 0

    for i, node in gdf.iterrows():
        dict_nodes[node["stop_name"]] = {}
        if len(xs) != len(ys):
            print("xs and ys is not same length")
            break
        
        temp_threshold = float('inf')
        for compare in range(len(xs)):
            if i == compare:
                continue
            dx = xs[i] - xs[compare]
            dy = ys[i] - ys[compare]
            d = np.hypot(dx, dy)
            other_stop = gdf.loc[compare, "stop_name"]
            dict_nodes[node["stop_name"]][other_stop] = d
            if d < temp_threshold:
                temp_threshold = d


        if temp_threshold > threshold:
            threshold = temp_threshold

    return threshold, dict_nodes


#def within_treshold(threshold, dict_nodes):
#    valid_connections = {}
#    for node, neighbors in dict_nodes.items():
#        valid_connections[node] = {} # delete this if the coments are removed
#        for connection, distance_between_stations in neighbors.items():
#            if distance_between_stations <= threshold:
#                valid_connections[node][connection] = distance_between_stations
#
#                #if node in valid_connections:
#                #    valid_connections[node].append(connection)
#                #else:
#                #    valid_connections[node][connection] = distance_between_stations
#
#    return valid_connections

def within_treshold(threshold, dict_nodes):
    valid_connections = {}
    for node, neighbors in dict_nodes.items():
        for connection, distance_between_stations in neighbors.items():
            if distance_between_stations <= threshold:
                if node in valid_connections:
                    valid_connections[node].append((connection, distance_between_stations))
                else:
                    valid_connections[node] = [(connection, distance_between_stations)]

    return valid_connections

# %%
valid_connections = within_treshold(1350, distance_dict)
valid_connections
# Out:
# {'Vestamager St. (Metro)': [('Ørestad St. (Metro)',
#    np.float64(1106.2645015954308))],
#  'Ørestad St. (Metro)': [('Vestamager St. (Metro)',
#    np.float64(1106.2645015954308)),
#   ('Bella Center St. (Metro)', np.float64(1025.9543236893055))],
#  'Sundby St. (Metro)': [('Bella Center St. (Metro)',
#    np.float64(815.0266625149286)),
#   ('DR Byen St. (Metro)', np.float64(1199.284698683579))],
#  'Bella Center St. (Metro)': [('Ørestad St. (Metro)',
#    np.float64(1025.9543236893055)),
#   ('Sundby St. (Metro)', np.float64(815.0266625149286))],
#  'Islands Brygge St. (Metro)': [('DR Byen St. (Metro)',
#    np.float64(879.7041766237545)),
#   ('Christianshavn St. (Metro)', np.float64(1036.3458210593176)),
#   ('Amagerbro St. (Metro)', np.float64(1114.6055504828446))],
#  'DR Byen St. (Metro)': [('Sundby St. (Metro)', np.float64(1199.284698683579)),
#   ('Islands Brygge St. (Metro)', np.float64(879.7041766237545)),
#   ('Amagerbro St. (Metro)', np.float64(1212.0297356595909))],
#  'Kongens Nytorv St. (Metro)': [('Christianshavn St. (Metro)',
#    np.float64(883.2902631493304)),
#   ('Nørreport St. (Metro)', np.float64(1031.8917684103494)),
#   ('Marmorkirken St. (Metro)', np.float64(707.7758080011234)),
#   ('Gammel Strand St. (Metro)', np.float64(389.86878121953464)),
#   ('Rådhuspladsen St. (Metro)', np.float64(1079.5742316564586))],
#  'Christianshavn St. (Metro)': [('Islands Brygge St. (Metro)',
#    np.float64(1036.3458210593176)),
#   ('Kongens Nytorv St. (Metro)', np.float64(883.2902631493304)),
#   ('Amagerbro St. (Metro)', np.float64(1213.1050956080787)),
#   ('Gammel Strand St. (Metro)', np.float64(976.6793517040718))],
#  'Forum St. (Metro)': [('Nørreport St. (Metro)',
#    np.float64(1192.1227297747755)),
#   ('Frederiksberg St. (Metro)', np.float64(1304.4461972848917)),
#   ('København H (Metro)', np.float64(1323.0256630961426)),
#   ('Frederiksberg Allé St. (Metro)', np.float64(1178.6948758236265)),
#   ('Aksel Møllers Have St. (Metro)', np.float64(1312.3494283976834)),
#   ('Nuuks Plads St. (Metro)', np.float64(981.2445993636211)),
#   ('Rådhuspladsen St. (Metro)', np.float64(1195.146888442759))],
#  'Nørreport St. (Metro)': [('Kongens Nytorv St. (Metro)',
#    np.float64(1031.8917684103494)),
#   ('Forum St. (Metro)', np.float64(1192.1227297747755)),
#   ('Marmorkirken St. (Metro)', np.float64(1117.1139050850813)),
#   ('Gammel Strand St. (Metro)', np.float64(864.9625311470426)),
#   ('Rådhuspladsen St. (Metro)', np.float64(843.4475198759454))],
#  'Fasanvej St. (Metro)': [('Frederiksberg St. (Metro)',
#    np.float64(544.2656885111104)),
#   ('Lindevang St. (Metro)', np.float64(674.2870268421151)),
#   ('Aksel Møllers Have St. (Metro)', np.float64(822.8834320606042))],
#  'Frederiksberg St. (Metro)': [('Forum St. (Metro)',
#    np.float64(1304.4461972848917)),
#   ('Fasanvej St. (Metro)', np.float64(544.2656885111104)),
#   ('Lindevang St. (Metro)', np.float64(1211.7421797934821)),
#   ('Frederiksberg Allé St. (Metro)', np.float64(995.5949669094437)),
#   ('Aksel Møllers Have St. (Metro)', np.float64(581.2571231374345)),
#   ('Nuuks Plads St. (Metro)', np.float64(1097.5128248168937))],
#  'Flintholm St. (Metro)': [('Lindevang St. (Metro)',
#    np.float64(880.4037821240897)),
#   ('Vanløse St. (Metro)', np.float64(519.4685936883482))],
#  'Lindevang St. (Metro)': [('Fasanvej St. (Metro)',
#    np.float64(674.2870268421151)),
#   ('Frederiksberg St. (Metro)', np.float64(1211.7421797934821)),
#   ('Flintholm St. (Metro)', np.float64(880.4037821240897)),
#   ('Aksel Møllers Have St. (Metro)', np.float64(1317.6571642666681))],
#  'Vanløse St. (Metro)': [('Flintholm St. (Metro)',
#    np.float64(519.4685936883482))],
#  'Lergravsparken St. (Metro)': [('Amagerbro St. (Metro)',
#    np.float64(859.649289516001)),
#   ('Øresund St. (Metro)', np.float64(758.7147393898872)),
#   ('Amager Strand St. (Metro)', np.float64(1138.9478192684217))],
#  'Amagerbro St. (Metro)': [('Islands Brygge St. (Metro)',
#    np.float64(1114.6055504828446)),
#   ('DR Byen St. (Metro)', np.float64(1212.0297356595909)),
#   ('Christianshavn St. (Metro)', np.float64(1213.1050956080787)),
#   ('Lergravsparken St. (Metro)', np.float64(859.649289516001))],
#  'Øresund St. (Metro)': [('Lergravsparken St. (Metro)',
#    np.float64(758.7147393898872)),
#   ('Amager Strand St. (Metro)', np.float64(609.5918092520749))],
#  'Amager Strand St. (Metro)': [('Lergravsparken St. (Metro)',
#    np.float64(1138.9478192684217)),
#   ('Øresund St. (Metro)', np.float64(609.5918092520749)),
#   ('Femøren St. (Metro)', np.float64(1313.946754139891))],
#  'Femøren St. (Metro)': [('Amager Strand St. (Metro)',
#    np.float64(1313.946754139891)),
#   ('Kastrup St. (Metro)', np.float64(1192.713835227626))],
#  'Kastrup St. (Metro)': [('Femøren St. (Metro)',
#    np.float64(1192.713835227626)),
#   ('Københavns Lufthavn St. (Metro)', np.float64(646.5514327812106))],
#  'Københavns Lufthavn St. (Metro)': [('Kastrup St. (Metro)',
#    np.float64(646.5514327812106))],
#  'København H (Metro)': [('Forum St. (Metro)', np.float64(1323.0256630961426)),
#   ('Enghave Plads St. (Metro)', np.float64(1263.0615969531916)),
#   ('Gammel Strand St. (Metro)', np.float64(1167.611210373912)),
#   ('Rådhuspladsen St. (Metro)', np.float64(574.6488609881841)),
#   ('Havneholmen St. (Metro)', np.float64(1263.0274310140617))],
#  'Enghave Plads St. (Metro)': [('København H (Metro)',
#    np.float64(1263.0615969531916)),
#   ('Frederiksberg Allé St. (Metro)', np.float64(795.3600927981114)),
#   ('Havneholmen St. (Metro)', np.float64(1112.2828975519085))],
#  'Frederiksberg Allé St. (Metro)': [('Forum St. (Metro)',
#    np.float64(1178.6948758236265)),
#   ('Frederiksberg St. (Metro)', np.float64(995.5949669094437)),
#   ('Enghave Plads St. (Metro)', np.float64(795.3600927981114))],
#  'Aksel Møllers Have St. (Metro)': [('Forum St. (Metro)',
#    np.float64(1312.3494283976834)),
#   ('Fasanvej St. (Metro)', np.float64(822.8834320606042)),
#   ('Frederiksberg St. (Metro)', np.float64(581.2571231374345)),
#   ('Lindevang St. (Metro)', np.float64(1317.6571642666681)),
#   ('Nuuks Plads St. (Metro)', np.float64(667.0568852002501)),
#   ('Nørrebros Runddel St. (Metro)', np.float64(1298.3994699546142))],
#  'Nuuks Plads St. (Metro)': [('Forum St. (Metro)',
#    np.float64(981.2445993636211)),
#   ('Frederiksberg St. (Metro)', np.float64(1097.5128248168937)),
#   ('Aksel Møllers Have St. (Metro)', np.float64(667.0568852002501)),
#   ('Nørrebros Runddel St. (Metro)', np.float64(686.4768115136213)),
#   ('Nørrebro St. (Metro)', np.float64(1343.2205312639023))],
#  'Nørrebros Runddel St. (Metro)': [('Aksel Møllers Have St. (Metro)',
#    np.float64(1298.3994699546142)),
#   ('Nuuks Plads St. (Metro)', np.float64(686.4768115136213)),
#   ('Nørrebro St. (Metro)', np.float64(1001.7583425997792)),
#   ('Skjolds Plads St. (Metro)', np.float64(1040.0547891565145))],
#  'Nørrebro St. (Metro)': [('Nuuks Plads St. (Metro)',
#    np.float64(1343.2205312639023)),
#   ('Nørrebros Runddel St. (Metro)', np.float64(1001.7583425997792)),
#   ('Skjolds Plads St. (Metro)', np.float64(706.7250764516783))],
#  'Skjolds Plads St. (Metro)': [('Nørrebros Runddel St. (Metro)',
#    np.float64(1040.0547891565145)),
#   ('Nørrebro St. (Metro)', np.float64(706.7250764516783)),
#   ('Vibenshus Runddel St. (Metro)', np.float64(1046.0208150606788))],
#  'Vibenshus Runddel St. (Metro)': [('Skjolds Plads St. (Metro)',
#    np.float64(1046.0208150606788)),
#   ('Poul Henningsens Plads St. (Metro)', np.float64(864.3811843688131)),
#   ('Trianglen St. (Metro)', np.float64(1099.5938441658616))],
#  'Poul Henningsens Plads St. (Metro)': [('Vibenshus Runddel St. (Metro)',
#    np.float64(864.3811843688131)),
#   ('Trianglen St. (Metro)', np.float64(1126.7542330445106)),
#   ('Nordhavn St. (Metro)', np.float64(975.1943466408769)),
#   ('Orientkaj St. (Metro)', np.float64(1195.9680602671353))],
#  'Trianglen St. (Metro)': [('Vibenshus Runddel St. (Metro)',
#    np.float64(1099.5938441658616)),
#   ('Poul Henningsens Plads St. (Metro)', np.float64(1126.7542330445106)),
#   ('Østerport St. (Metro)', np.float64(880.1237593714173)),
#   ('Nordhavn St. (Metro)', np.float64(1344.548729201505))],
#  'Østerport St. (Metro)': [('Trianglen St. (Metro)',
#    np.float64(880.1237593714173)),
#   ('Marmorkirken St. (Metro)', np.float64(911.1217526932213))],
#  'Marmorkirken St. (Metro)': [('Kongens Nytorv St. (Metro)',
#    np.float64(707.7758080011234)),
#   ('Nørreport St. (Metro)', np.float64(1117.1139050850813)),
#   ('Østerport St. (Metro)', np.float64(911.1217526932213)),
#   ('Gammel Strand St. (Metro)', np.float64(1010.3803158602373))],
#  'Gammel Strand St. (Metro)': [('Kongens Nytorv St. (Metro)',
#    np.float64(389.86878121953464)),
#   ('Christianshavn St. (Metro)', np.float64(976.6793517040718)),
#   ('Nørreport St. (Metro)', np.float64(864.9625311470426)),
#   ('København H (Metro)', np.float64(1167.611210373912)),
#   ('Marmorkirken St. (Metro)', np.float64(1010.3803158602373)),
#   ('Rådhuspladsen St. (Metro)', np.float64(694.7091043939593))],
#  'Rådhuspladsen St. (Metro)': [('Kongens Nytorv St. (Metro)',
#    np.float64(1079.5742316564586)),
#   ('Forum St. (Metro)', np.float64(1195.146888442759)),
#   ('Nørreport St. (Metro)', np.float64(843.4475198759454)),
#   ('København H (Metro)', np.float64(574.6488609881841)),
#   ('Gammel Strand St. (Metro)', np.float64(694.7091043939593))],
#  'Nordhavn St. (Metro)': [('Poul Henningsens Plads St. (Metro)',
#    np.float64(975.1943466408769)),
#   ('Trianglen St. (Metro)', np.float64(1344.548729201505)),
#   ('Orientkaj St. (Metro)', np.float64(526.6232825740493))],
#  'Orientkaj St. (Metro)': [('Poul Henningsens Plads St. (Metro)',
#    np.float64(1195.9680602671353)),
#   ('Nordhavn St. (Metro)', np.float64(526.6232825740493))],
#  'København Syd St. (Metro)': [('Mozarts Plads St. (Metro)',
#    np.float64(1169.4813019946187))],
#  'Havneholmen St. (Metro)': [('København H (Metro)',
#    np.float64(1263.0274310140617)),
#   ('Enghave Plads St. (Metro)', np.float64(1112.2828975519085)),
#   ('Enghave Brygge St. (Metro)', np.float64(821.2860108495125))],
#  'Enghave Brygge St. (Metro)': [('Havneholmen St. (Metro)',
#    np.float64(821.2860108495125)),
#   ('Sluseholmen St. (Metro)', np.float64(1179.3110468852813))],
#  'Sluseholmen St. (Metro)': [('Enghave Brygge St. (Metro)',
#    np.float64(1179.3110468852813)),
#   ('Mozarts Plads St. (Metro)', np.float64(712.6368438714211))],
#  'Mozarts Plads St. (Metro)': [('København Syd St. (Metro)',
#    np.float64(1169.4813019946187)),
#   ('Sluseholmen St. (Metro)', np.float64(712.6368438714211))]}

# %%
max_distance, distance_dict = neighbore_threshold_and_edge_dist(gdf_stops_3857)

# %%
max_distance
# Out:
# np.float64(1192.713835227626)

# %%
# Parameters
max_routes = 4
max_stops = 17
min_stops = 13
threshold = 1350
_, distance_dict = neighbore_threshold_and_edge_dist(gdf_stops_3857)

generations = {}
generation_id = 0

all_routes = {}
potential_start = list(G.nodes)

valid_connections = within_treshold(threshold, distance_dict)

routes = 1
while routes < max_routes+1:
    route_current = []
    start_node = random.choice(potential_start)
    route_current.append(start_node)

    while len(route_current) < max_stops:
        curr_node = route_current[-1]
        
        if curr_node in potential_start:
            potential_start.remove(curr_node)
        
        poss_neighbors = valid_connections[curr_node]
        #poss_neighbors = [n for n in poss_neighbors if n not in route_current]

        lowest_distance = float('inf')
        for i in poss_neighbors:
            if i[0] in route_current:
                poss_neighbors.remove(i)
            if i[1] < lowest_distance:
                lowest_distance = i[1]
                closest_neightbor = i[0]
        
        if poss_neighbors == []:
            if len(route_current) < min_stops:
                route_current.reverse()
                curr_node = route_current[-1]
                poss_neighbors = valid_connections[curr_node]
                for i in poss_neighbors:
                    if i[0] in route_current:
                        poss_neighbors.remove(i)
                    if i[1] < lowest_distance:
                        lowest_distance = i[1]
                        closest_neightbor = i[0]
            else:
                break
        #random_neighbor = random.choice(poss_neighbors)
        route_current.append(closest_neightbor)

        #break_condition = random.random()
        #if break_condition < :
        #    break

    all_routes[routes] = {}
    all_routes[routes]["nodes"] = route_current

    routes += 1

all_routes
# Out:
# {1: {'nodes': ['Enghave Brygge St. (Metro)',
#    'Havneholmen St. (Metro)',
#    'Enghave Brygge St. (Metro)',
#    'Sluseholmen St. (Metro)',
#    'København Syd St. (Metro)',
#    'Mozarts Plads St. (Metro)',
#    'København Syd St. (Metro)',
#    'Mozarts Plads St. (Metro)',
#    'Sluseholmen St. (Metro)',
#    'Mozarts Plads St. (Metro)',
#    'Havneholmen St. (Metro)',
#    'Enghave Plads St. (Metro)',
#    'Frederiksberg Allé St. (Metro)',
#    'Enghave Plads St. (Metro)',
#    'Frederiksberg Allé St. (Metro)',
#    'Frederiksberg St. (Metro)',
#    'Fasanvej St. (Metro)']},
#  2: {'nodes': ['Kongens Nytorv St. (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Kongens Nytorv St. (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'København H (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'København H (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'Nørreport St. (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Nørreport St. (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'Nørreport St. (Metro)',
#    'Marmorkirken St. (Metro)',
#    'Kongens Nytorv St. (Metro)']},
#  3: {'nodes': ['Vestamager St. (Metro)',
#    'Vestamager St. (Metro)',
#    'Ørestad St. (Metro)',
#    'Sundby St. (Metro)',
#    'DR Byen St. (Metro)',
#    'Sundby St. (Metro)',
#    'Bella Center St. (Metro)',
#    'Sundby St. (Metro)',
#    'Bella Center St. (Metro)',
#    'Ørestad St. (Metro)',
#    'Bella Center St. (Metro)',
#    'Ørestad St. (Metro)',
#    'Vestamager St. (Metro)']},
#  4: {'nodes': ['Vanløse St. (Metro)',
#    'Flintholm St. (Metro)',
#    'Flintholm St. (Metro)',
#    'Lindevang St. (Metro)',
#    'Fasanvej St. (Metro)',
#    'Frederiksberg St. (Metro)',
#    'Fasanvej St. (Metro)',
#    'Frederiksberg St. (Metro)',
#    'Nuuks Plads St. (Metro)',
#    'Nørrebros Runddel St. (Metro)',
#    'Nuuks Plads St. (Metro)',
#    'Aksel Møllers Have St. (Metro)',
#    'Fasanvej St. (Metro)']}}

# %%
import random

# Parameters
max_routes = 4
max_stops = 17
min_stops = 13
threshold = 1350

_, distance_dict = neighbore_threshold_and_edge_dist(gdf_stops_3857)
valid_connections = within_treshold(threshold, distance_dict)

all_routes = {}
potential_start = list(G.nodes)

used_nodes = set()  # <-- nodes already used in ANY completed route

routes = 1
while routes < max_routes + 1:

    if not potential_start:
        break

    route_current = []
    start_node = random.choice(potential_start)
    route_current.append(start_node)

    while len(route_current) < max_stops:
        curr_node = route_current[-1]

        if curr_node in potential_start:
            potential_start.remove(curr_node)

        if curr_node not in valid_connections:
            break

        # filter out nodes already in this route
        poss_neighbors = [n for n in valid_connections[curr_node] if n[0] not in route_current]

        # dead-end handling
        if not poss_neighbors:
            if len(route_current) < min_stops:
                route_current.reverse()
                curr_node = route_current[-1]

                if curr_node not in valid_connections:
                    break

                poss_neighbors = [n for n in valid_connections[curr_node] if n[0] not in route_current]
                if not poss_neighbors:
                    break
            else:
                break

        # PRIORITIZE nodes not used in any previous route, else shortest distance
        fresh = [t for t in poss_neighbors if t[0] not in used_nodes]
        pick_from = fresh if fresh else poss_neighbors
        next_node = min(pick_from, key=lambda x: x[1])[0]

        route_current.append(next_node)

    all_routes[routes] = {"nodes": route_current}
    used_nodes.update(route_current)  # <-- mark whole route as "used" for future prioritization
    routes += 1

all_routes
# Out:
# {1: {'nodes': ['Vanløse St. (Metro)',
#    'Flintholm St. (Metro)',
#    'Lindevang St. (Metro)',
#    'Fasanvej St. (Metro)',
#    'Frederiksberg St. (Metro)',
#    'Aksel Møllers Have St. (Metro)',
#    'Nuuks Plads St. (Metro)',
#    'Nørrebros Runddel St. (Metro)',
#    'Nørrebro St. (Metro)',
#    'Skjolds Plads St. (Metro)',
#    'Vibenshus Runddel St. (Metro)',
#    'Poul Henningsens Plads St. (Metro)',
#    'Nordhavn St. (Metro)',
#    'Orientkaj St. (Metro)']},
#  2: {'nodes': ['Orientkaj St. (Metro)',
#    'Nordhavn St. (Metro)',
#    'Poul Henningsens Plads St. (Metro)',
#    'Vibenshus Runddel St. (Metro)',
#    'Trianglen St. (Metro)',
#    'Østerport St. (Metro)',
#    'Marmorkirken St. (Metro)',
#    'Kongens Nytorv St. (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'København H (Metro)',
#    'Havneholmen St. (Metro)',
#    'Enghave Brygge St. (Metro)',
#    'Sluseholmen St. (Metro)',
#    'Mozarts Plads St. (Metro)',
#    'København Syd St. (Metro)']},
#  3: {'nodes': ['Københavns Lufthavn St. (Metro)',
#    'Kastrup St. (Metro)',
#    'Femøren St. (Metro)',
#    'Amager Strand St. (Metro)',
#    'Øresund St. (Metro)',
#    'Lergravsparken St. (Metro)',
#    'Amagerbro St. (Metro)',
#    'Islands Brygge St. (Metro)',
#    'DR Byen St. (Metro)',
#    'Sundby St. (Metro)',
#    'Bella Center St. (Metro)',
#    'Ørestad St. (Metro)',
#    'Vestamager St. (Metro)']},
#  4: {'nodes': ['København Syd St. (Metro)',
#    'Mozarts Plads St. (Metro)',
#    'Sluseholmen St. (Metro)',
#    'Enghave Brygge St. (Metro)',
#    'Havneholmen St. (Metro)',
#    'Enghave Plads St. (Metro)',
#    'Frederiksberg Allé St. (Metro)',
#    'Forum St. (Metro)',
#    'Nørreport St. (Metro)',
#    'Rådhuspladsen St. (Metro)',
#    'København H (Metro)',
#    'Gammel Strand St. (Metro)',
#    'Christianshavn St. (Metro)',
#    'Kongens Nytorv St. (Metro)',
#    'Marmorkirken St. (Metro)',
#    'Østerport St. (Metro)',
#    'Trianglen St. (Metro)']}}

# %%
def create_line(p1_name, p2_name, gdf_stops_3857):
    p1 = gdf_stops_3857.loc[gdf_stops_3857["stop_name"] == p1_name, "geometry"].iloc[0]
    p2 = gdf_stops_3857.loc[gdf_stops_3857["stop_name"] == p2_name, "geometry"].iloc[0]
    return LineString([p1, p2])

records = []

for i in all_routes:
    route = all_routes[i]["nodes"]

    for k in range(len(route) - 1):
        p1 = route[k]
        p2 = route[k + 1]
        lines = create_line(p1, p2, gdf_stops_3857)

        records.append({
            "geometry": lines,
            "route_id": i
        })

edges_gdf = gpd.GeoDataFrame(records, crs=gdf_stops_3857.crs)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))

edges_gdf.plot(
    ax=ax,
    column="route_id",     # color by route
    categorical=True,
    legend=True,
    linewidth=3
)

gdf_stops_3857.plot(ax=ax, color="blue", markersize=8)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron, crs=gdf_stops_3857.crs)

ax.set_axis_off()
ax.set_aspect("equal")
plt.show()
